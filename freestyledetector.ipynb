# %% [markdown]
# # Práctica 5
#
# ## Autora
# [Andrea Santana López]("https://github.com/AndreaSantaloz")

# %% [markdown]
# ## Primero paso
# Se importará  las librerías y módulos necesarios para la prática

# %%
import cv2
from deepface import DeepFace

# %% [markdown]
# ## Segundo paso

# %%
from deepface import DeepFace

DeepFace.stream(
    db_path="./archive/lfw-deepfunneled/lfw-deepfunneled/",
    model_name = "OpenFace",
    detector_backend="opencv",
    enable_face_analysis=False,
    time_threshold=3,
    frame_threshold=10,
)
# Out:
# WARNING:tensorflow:From c:\Users\andsa\anaconda3\envs\detector\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 25-11-13 13:09:41 - 🔗 openface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5 to C:\Users\andsa\.deepface\weights\openface_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5
# To: C:\Users\andsa\.deepface\weights\openface_weights.h5
# 100%|██████████| 15.3M/15.3M [00:06<00:00, 2.53MB/s]
# 25-11-13 13:09:48 - OpenFace is built

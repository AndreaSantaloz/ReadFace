# %% [markdown]
# # Práctica 5
#
# ## Autora
# [Andrea Santana López]("https://github.com/AndreaSantaloz")

# %% [markdown]
# Se ha decidido realizar un filtro de cara donde se aumente los ojos y aumente la  boca con
# unas decoraciones.Este esta inspirado en uno ya hecho de ticktock.
